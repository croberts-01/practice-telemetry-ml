# %%
import sys
from pathlib import Path

# Add project root to Python path
PROJECT_ROOT = Path.cwd().parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

print("Added to sys.path:", PROJECT_ROOT)
# Out:
# Added to sys.path: /Users/croberts/practice-telemetry-ml

# %%
import pandas as pd

from src.config import RAW_TELEMETRY_PATH

# %%
df_raw = pd.read_parquet(RAW_TELEMETRY_PATH)
df_raw.head()
# Out:
#   device_id           timestamp  sensor_value     temp_c  battery_v  \
# 0      D000 2025-12-11 21:32:00      9.833085  19.594316   3.908354
# 1      D000 2025-12-11 21:47:00     11.005451  19.998744   3.911803
# 2      D000 2025-12-11 22:02:00     11.217204  20.449461   3.901991
# 3      D000 2025-12-11 22:17:00      9.579090  20.673206   3.898062
# 4      D000 2025-12-11 22:32:00     10.063996  22.027144   3.903768
#
#         rssi event_tag
# 0 -55.495804    normal
# 1 -56.698568    normal
# 2 -55.531041    normal
# 3 -54.816955    normal
# 4 -52.331760    normal

# %%
df_raw.shape
# Out:
# (33667, 7)

# %%
df_raw.columns
# Out:
# Index(['device_id', 'timestamp', 'sensor_value', 'temp_c', 'battery_v', 'rssi',
#        'event_tag'],
#       dtype='object')

# %%
df = df_raw.copy()
df["timestamp"] = pd.to_datetime(df["timestamp"], errors = "coerce")

df = df.sort_values(["device_id", "timestamp"]).reset_index(drop=True)
df.head()
# Out:
#   device_id           timestamp  sensor_value     temp_c  battery_v  \
# 0      D000 2025-12-11 21:32:00      9.833085  19.594316   3.908354
# 1      D000 2025-12-11 21:47:00     11.005451  19.998744   3.911803
# 2      D000 2025-12-11 22:02:00     11.217204  20.449461   3.901991
# 3      D000 2025-12-11 22:17:00      9.579090  20.673206   3.898062
# 4      D000 2025-12-11 22:32:00     10.063996  22.027144   3.903768
#
#         rssi event_tag
# 0 -55.495804    normal
# 1 -56.698568    normal
# 2 -55.531041    normal
# 3 -54.816955    normal
# 4 -52.331760    normal

# %%
d0 = df[df["device_id"] == df["device_id"].iloc[0]].copy()
d0[["device_id", "timestamp", "sensor_value", "temp_c", "rssi", "event_tag"]].head(10)
# Out:
#   device_id           timestamp  sensor_value     temp_c       rssi event_tag
# 0      D000 2025-12-11 21:32:00      9.833085  19.594316 -55.495804    normal
# 1      D000 2025-12-11 21:47:00     11.005451  19.998744 -56.698568    normal
# 2      D000 2025-12-11 22:02:00     11.217204  20.449461 -55.531041    normal
# 3      D000 2025-12-11 22:17:00      9.579090  20.673206 -54.816955    normal
# 4      D000 2025-12-11 22:32:00     10.063996  22.027144 -52.331760    normal
# 5      D000 2025-12-11 22:47:00     11.015939  20.220630 -55.297635    normal
# 6      D000 2025-12-11 23:02:00     10.841355  22.603017 -53.802690    normal
# 7      D000 2025-12-11 23:17:00     11.110428  21.907694 -56.624801    normal
# 8      D000 2025-12-11 23:32:00     10.695249  22.801558 -53.283713    normal
# 9      D000 2025-12-11 23:47:00     11.818070  21.876261 -53.872809    normal

# %%
d0["timestamp"].is_monotonic_increasing
# Out:
# True

# %%
feature_cols = ["sensor_value", "temp_c", "rssi"]
lags = [1, 2, 4]

g = df.groupby("device_id", group_keys=False)

for col in feature_cols:
    for k in lags:
        df[f"{col}_lag_{k}"] = g[col].shift(k)

# %%
cols_to_view = ["timestamp", "sensor_value", "sensor_value_lag_1", "sensor_value_lag_2", "sensor_value_lag_4", "event_tag"]
d0 = df[df["device_id"] == df["device_id"].iloc[0]].copy()
d0[cols_to_view].head(12)
# Out:
#              timestamp  sensor_value  sensor_value_lag_1  sensor_value_lag_2  \
# 0  2025-12-11 21:32:00      9.833085                 NaN                 NaN
# 1  2025-12-11 21:47:00     11.005451            9.833085                 NaN
# 2  2025-12-11 22:02:00     11.217204           11.005451            9.833085
# 3  2025-12-11 22:17:00      9.579090           11.217204           11.005451
# 4  2025-12-11 22:32:00     10.063996            9.579090           11.217204
# 5  2025-12-11 22:47:00     11.015939           10.063996            9.579090
# 6  2025-12-11 23:02:00     10.841355           11.015939           10.063996
# 7  2025-12-11 23:17:00     11.110428           10.841355           11.015939
# 8  2025-12-11 23:32:00     10.695249           11.110428           10.841355
# 9  2025-12-11 23:47:00     11.818070           10.695249           11.110428
# 10 2025-12-12 00:02:00     11.836893           11.818070           10.695249
# 11 2025-12-12 00:17:00     11.485713           11.836893           11.818070
#
#     sensor_value_lag_4 event_tag
# 0                  NaN    normal
# 1                  NaN    normal
# 2                  NaN    normal
# 3                  NaN    normal
# 4             9.833085    normal
# 5            11.005451    normal
# 6            11.217204    normal
# 7             9.579090    normal
# 8            10.063996    normal
# 9            11.015939    normal
# 10           10.841355    normal
# 11           11.110428    normal

# %%
i = 10
d0.iloc[i][["sensor_value", "sensor_value_lag_1", "sensor_value_lag_2"]]
# Out:
# sensor_value          11.836893
# sensor_value_lag_1     11.81807
# sensor_value_lag_2    10.695249
# Name: 10, dtype: object

# %%
w = 4  # 4 rows = 1 hour at 15-min cadence

for col in feature_cols:
    past = g[col].shift(1)  # <-- leakage prevention
    df[f"{col}_roll_mean_{w}"] = past.groupby(df["device_id"]).rolling(window=w, min_periods=w).mean().reset_index(level=0, drop=True)
    df[f"{col}_roll_std_{w}"]  = past.groupby(df["device_id"]).rolling(window=w, min_periods=w).std().reset_index(level=0, drop=True)

# %%
cols = ["timestamp", "sensor_value", "sensor_value_lag_1", f"sensor_value_roll_mean_{w}", f"sensor_value_roll_std_{w}", "event_tag"]
d0 = df[df["device_id"] == df["device_id"].iloc[0]].copy()
d0[cols].head(15)
# Out:
#              timestamp  sensor_value  sensor_value_lag_1  \
# 0  2025-12-11 21:32:00      9.833085                 NaN
# 1  2025-12-11 21:47:00     11.005451            9.833085
# 2  2025-12-11 22:02:00     11.217204           11.005451
# 3  2025-12-11 22:17:00      9.579090           11.217204
# 4  2025-12-11 22:32:00     10.063996            9.579090
# 5  2025-12-11 22:47:00     11.015939           10.063996
# 6  2025-12-11 23:02:00     10.841355           11.015939
# 7  2025-12-11 23:17:00     11.110428           10.841355
# 8  2025-12-11 23:32:00     10.695249           11.110428
# 9  2025-12-11 23:47:00     11.818070           10.695249
# 10 2025-12-12 00:02:00     11.836893           11.818070
# 11 2025-12-12 00:17:00     11.485713           11.836893
# 12 2025-12-12 00:32:00     12.194081           11.485713
# 13 2025-12-12 00:47:00     11.865341           12.194081
# 14 2025-12-12 01:02:00     11.131530           11.865341
#
#     sensor_value_roll_mean_4  sensor_value_roll_std_4 event_tag
# 0                        NaN                      NaN    normal
# 1                        NaN                      NaN    normal
# 2                        NaN                      NaN    normal
# 3                        NaN                      NaN    normal
# 4                  10.408707                 0.822471    normal
# 5                  10.466435                 0.775356    normal
# 6                  10.469057                 0.777800    normal
# 7                  10.375095                 0.672925    normal
# 8                  10.757930                 0.475860    normal
# 9                  10.915743                 0.184474    normal
# 10                 11.116276                 0.498462    normal
# 11                 11.365160                 0.560157    normal
# 12                 11.458981                 0.534092    normal
# 13                 11.833689                 0.289381    normal
# 14                 11.845507                 0.289496    normal

# %%
i = 10
prev4 = d0["sensor_value"].iloc[i-4:i]  # these are rows i-4, i-3, i-2, i-1
prev4.mean(), d0[f"sensor_value_roll_mean_{w}"].iloc[i]
# Out:
# (np.float64(11.116275547599239), np.float64(11.116275547599239))
